# %% [markdown]
# # 01 — Recommendation Eval (THS2026-66)
#
# Đo **Precision@10, NDCG@10, ILS** cho module gợi ý nhà trọ.
#
# Ngưỡng đạt: P@10 ≥0.6 · NDCG@10 ≥0.65 · ILS ≤0.7. Xem `Technical_Roadmap.md` T5/T6.

# %%
import sys, json
sys.path.append('..')
from metrics import precision_at_k, ndcg_at_k, intra_list_similarity
import numpy as np

# %% [markdown]
# ## 1. Load user-mock + ground-truth relevance
#
# `data/user_mock.json`: list các user, mỗi user có `id`, `preference_vector`, và `relevant` (phòng liên quan + gain).

# %%
with open('../data/user_mock.json', encoding='utf-8') as f:
    users = json.load(f)
print(f'{len(users)} user-mock')  # target >=30

# %% [markdown]
# ## 2. Gọi recommender (thay bằng API thật khi sẵn sàng)

# %%
def get_recommendations(user, k=10):
    # TODO: call GET /api/recommend/{user['id']}?k={k}
    # return list listing_id theo thứ tự score giảm dần
    raise NotImplementedError('Nối API recommend ở Sprint 3')

# %% [markdown]
# ## 3. Tính metric trên toàn bộ user-mock

# %%
def listing_sim(a, b):
    # cosine giữa 2 embedding listing; thay bằng vector thật
    return 0.0

p_scores, ndcg_scores, ils_scores = [], [], []
for u in users:
    rec = get_recommendations(u, k=10)
    relevant_set = set(u['relevant'].keys())
    relevance = {k: v for k, v in u['relevant'].items()}
    p_scores.append(precision_at_k(rec, relevant_set, 10))
    ndcg_scores.append(ndcg_at_k(rec, relevance, 10))
    ils_scores.append(intra_list_similarity(rec, listing_sim))

print('P@10  =', round(np.mean(p_scores), 4),  '(>=0.6)')
print('NDCG  =', round(np.mean(ndcg_scores), 4), '(>=0.65)')
print('ILS   =', round(np.mean(ils_scores), 4),  '(<=0.7)')
